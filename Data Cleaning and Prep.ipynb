# %%
import pandas as pd

# %%
VDem = pd.read_csv('C:/Users/danif/Downloads/V-Dem-CY-FullOthers_csv_v13/V-Dem-CY-Full+Others-v13.csv')
# Out:
# C:\Users\danif\AppData\Local\Temp\ipykernel_34544\2553934447.py:1: DtypeWarning: Columns (364,365,366,394,410,821,831,832,930,1235,1252,1481,3063,3282,3283,3351,3353,3357,3358,3360,3361,3362) have mixed types. Specify dtype option on import or set low_memory=False.
#   VDem = pd.read_csv('C:/Users/danif/Downloads/V-Dem-CY-FullOthers_csv_v13/V-Dem-CY-Full+Others-v13.csv')

# %%
VDem.head()

VDem_2000s = VDem.loc[VDem['year'] >=2000]
VDem_2000s.head()
# Out:
#     country_name country_text_id  country_id  year historical_date  project  \
# 211       Mexico             MEX           3  2000      2000-12-31        0
# 212       Mexico             MEX           3  2001      2001-12-31        0
# 213       Mexico             MEX           3  2002      2002-12-31        0
# 214       Mexico             MEX           3  2003      2003-12-31        0
# 215       Mexico             MEX           3  2004      2004-12-31        0
#
#      historical               histname  codingstart  codingend  ...  \
# 211           1  United Mexican States         1789       2022  ...
# 212           1  United Mexican States         1789       2022  ...
# 213           1  United Mexican States         1789       2022  ...
# 214           1  United Mexican States         1789       2022  ...
# 215           1  United Mexican States         1789       2022  ...
#
#      e_pefeliex  e_peinfmor  e_pelifeex  e_pematmor     e_wb_pop  e_civil_war  \
# ...

# %%
VDem_grouped = VDem_2000s.groupby('country_name').mean()
VDem_grouped.head()
# Out:
#               country_id    year  project  historical  codingstart  codingend  \
# country_name
# Afghanistan         36.0  2011.0      0.0         1.0       1789.0     2022.0
# Albania             12.0  2011.0      0.0         0.0       1912.0     2022.0
# Algeria            103.0  2011.0      0.0         0.0       1900.0     2022.0
# Angola             104.0  2011.0      0.0         0.0       1900.0     2022.0
# Argentina           37.0  2011.0      0.0         1.0       1789.0     2022.0
#
#               codingstart_contemp  codingend_contemp  codingstart_hist  \
# country_name
# Afghanistan                1900.0             2022.0            1789.0
# Albania                    1912.0             2022.0               NaN
# Algeria                    1900.0             2022.0               NaN
# Angola                     1900.0             2022.0               NaN
# Argentina                  1900.0             2022.0            1789.0
#
# ...

# %%
VDem_GDP = VDem_grouped[['e_peaveduc', 'e_gdppc']]
VDem_GDP.head()
# Out:
#               e_peaveduc   e_gdppc
# country_name
# Afghanistan     3.500783   1.38680
# Albania              NaN   8.33260
# Algeria         7.096739  11.30095
# Angola          2.838913   5.07685
# Argentina       8.674348  15.32280

# %%
VDem_GDP.columns
# Out:
# Index(['e_peaveduc', 'e_gdppc'], dtype='object')

# %%
VDem_grouped.columns
# Out:
# Index(['country_id', 'year', 'project', 'historical', 'codingstart',
#        'codingend', 'codingstart_contemp', 'codingend_contemp',
#        'codingstart_hist', 'codingend_hist',
#        ...
#        'e_pefeliex', 'e_peinfmor', 'e_pelifeex', 'e_pematmor', 'e_wb_pop',
#        'e_civil_war', 'e_miinteco', 'e_miinterc', 'e_pt_coup',
#        'e_pt_coup_attempts'],
#       dtype='object', length=4573)

# %%
VDem_grouped['v2x_polyarchy'].head()
# Out:
# country_name
# Afghanistan    0.306304
# Albania        0.501130
# Algeria        0.318522
# Angola         0.257957
# Argentina      0.794783
# Name: v2x_polyarchy, dtype: float64

# %%
VDem_grouped['v2x_libdem'].head()
# Out:
# country_name
# Afghanistan    0.169565
# Albania        0.416087
# Algeria        0.162000
# Angola         0.122043
# Argentina      0.629826
# Name: v2x_libdem, dtype: float64

# %%
VDem_Index_Means = (VDem_grouped['v2x_polyarchy'] + VDem_grouped['v2x_libdem'] + VDem_grouped['v2x_partipdem'] + VDem_grouped['v2x_delibdem'] + VDem_grouped['v2x_egaldem'])/5

# %%
VDem_Index_Means
# Out:
# country_name
# Afghanistan    0.208130
# Albania        0.385922
# Algeria        0.222522
# Angola         0.134322
# Argentina      0.643357
#                  ...
# Vietnam        0.164330
# Yemen          0.140452
# Zambia         0.365296
# Zanzibar       0.233704
# Zimbabwe       0.212130
# Length: 179, dtype: float64
